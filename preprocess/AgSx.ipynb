# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_df = pd.read_csv('titanic.csv')

# %%
import seaborn as sns

# 나이 밀집도 시각화
sns.distplot(data_df['Age'], rug=True)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
data_df = pd.read_csv('titanic.csv')

#결측치를 뺀 Age 평균값
df_ag_mean = data_df['Age'].mean() #평균 == 29.699

#결측치를 평균값으로 채워라
data_df['Age'] = data_df['Age'].fillna(df_ag_mean)

#나이 밀집도 시각화
sns.distplot(new_df['Age'], rug=True)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
data_df = pd.read_csv('titanic.csv')

#결측치를 뺀 rms
df_ag_rms = np.sqrt(np.mean(data_df['Age'].dropna()**2)) #rms == 33.0569

#결측치를 rms로 채워라
data_df['Age'] = data_df['Age'].fillna(df_ag_rms)

#나이 밀집도 시각화
sns.distplot(new_df['Age'], rug=True)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
data_df = pd.read_csv('titanic.csv')
# male == 1 female == 2
data_df['Sex'] = data_df['Sex'].replace(['male', 'female'],[1, 2])

data_df['Sex']
# Out:
# 0      1
# 1      2
# 2      2
# 3      2
# 4      1
#       ..
# 886    1
# 887    2
# 888    2
# 889    1
# 890    1
# Name: Sex, Length: 891, dtype: int64

# %%
data_df = pd.read_csv('titanic.csv')

# %%
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    2  38.0      1
# 2                               Heikkinen, Miss. Laina    2  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    2  35.0      1
# 4                             Allen, Mr. William Henry    1  35.0      0
# ..                                                 ...  ...   ...    ...
# ...
